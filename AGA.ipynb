# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, BatchNormalization
from tensorflow.keras import optimizers, losses, metrics, models
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
import os
import random

# 不显示警告信息
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

stock_list = {"Apple":3400,"Microsoft":3400,"Google":2800,"Tesla":1800}

best_model_result = 0
best_gene = []  # 初始化一个保存最优参数组合的列表
stock_name = ""
s_length = 0

def load_data():
    target_stock = pd.read_csv("./data/n_"+stock_name+".csv")
    target_stock = pd.DataFrame(target_stock)
    # 时间点长度
    time_stamp = 50
    # 划分训练集与验证集
    target_stock = target_stock[['Open', 'High', 'Low', 'Close', 'Volume']]  # 'Volume'

    # 新增一列正负表示涨跌
    close = target_stock['Close'].tolist()
    y = []
    for i in range(len(target_stock) - 1):
        if close[i + 1] >= close[i]:
            y.append(1)
        else:
            y.append(-1)
    y.append(0)

    v4 = []
    for i in range(len(target_stock) - time_stamp - 1):
        if (y[i + time_stamp - 2] == 1):
            v4.append(1)
        else:
            v4.append(0)
    v4.append(0)
    target_stock["trend"] = y
    # 归一化
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(target_stock)
    
    train = scaled_data[0:s_length + time_stamp]
    test = scaled_data[s_length - time_stamp:]
    # 训练集
    x_train, y_train = [], []
    for i in range(len(train) - time_stamp):
        train[i + time_stamp - 1][5] = v4[i]
        x_train.append(train[i:i + time_stamp])
        y_train.append(train[i + time_stamp, 3])

    x_train, y_train = np.array(x_train), np.array(y_train)
    # 测试集
    x_test, y_test = [], []
    for i in range(len(test) - time_stamp):
        test[i + time_stamp - 1][5] = v4[i + s_length - time_stamp]
        x_test.append(test[i:i + time_stamp])
        y_test.append(test[i + time_stamp, 3])

    x_test, y_test = np.array(x_test), np.array(y_test)

    return x_train, x_test, y_train, y_test

def transncomp(closing_price, y_valid):
    # preprocessing,ues list
    y_valid = y_valid.reshape(-1)
    closing_price = np.array(closing_price)
    closing_price.reshape(-1)

    # temp1
    y_valid.tolist()
    temp1 = []
    for i in range(len(y_valid) - 1):
        if y_valid[i + 1] >= y_valid[i]:
            temp1.append(1)
        else:
            temp1.append(-1)

    # temp2
    closing_price.tolist()
    temp2 = []
    for i in range(len(closing_price) - 1):
        if closing_price[i + 1] >= closing_price[i]:
            temp2.append(1)
        else:
            temp2.append(-1)

    # compare
    sum = 0
    for i, j in zip(temp1, temp2):
        if i == j:
            sum += 1
    acc = sum / len(y_valid)
    return acc


def lstm_mode(inputs, units_num, sequences_state):
    # input主要是用来定义lstm的输入，input的一般是在第一层lstm层之前，units_num即是隐藏层神经元个数，sequence_state即是lstm层输出的方式
    lstm = LSTM(units_num, return_sequences=sequences_state)(inputs)
    # print("lstm:", lstm.shape)
    return lstm


# 定义全连接层、BN层
def dense_mode(input, dropout, units_num):
    # 这里主要定义全连接层的输入，input参数定义dense的第一次输入，units_num代表隐藏层神经元个数
    # 这里定义全连接层，采用L2正则化来防止过拟合，激活函数为relu
    dense = Dense(units_num, kernel_regularizer=tf.keras.regularizers.l2(0.001), activation='tanh')(input)
    # print("dense：", dense.shape)
    # 定义dropout层，概率为0.2
    drop_out = Dropout(rate=dropout)(dense)
    # 定义BN层，可以理解为是隐藏层的标准化过程
    # dense_bn = BatchNormalization()(drop_out)
    return dense, drop_out


# 这里定义的即是评价lstm效果的函数——也是遗传算法的适应度函数
def aim_function(x_train, y_train, x_test, y_test, num):
    # 这里传入数据和参数数组num,num保存了需要优化的参数
    # 这里我们设置num数组中num[0]代表lstm的层数。
    global best_model_result
    lstm_layers = num[0]
    # num[2:2 + lstm_layers]分别为lstm各层的神经元个数，num(1)为全连接层的层数)
    lstm_units = num[2:2 + lstm_layers]
    # 将num
    lstm_name = list(np.zeros((lstm_layers,)))
    # 设置全连接层的参数
    # num(1)为全连接的参数
    lstm_dense_layers = num[1]
    # 将lstm层之后的地方作为全连接层各层的参数
    lstm_dense_units = num[2 + lstm_layers: 2 + lstm_layers + lstm_dense_layers]
    #
    lstm_dense_name = list(np.zeros((lstm_dense_layers,)))
    lstm_dense_dropout_name = list(np.zeros((lstm_dense_layers,)))

    dropout = num[2 + lstm_layers + lstm_dense_layers]
    epochs = int(num[2 + lstm_layers + lstm_dense_layers + 1])

    # 这主要是定义lstm的第一层输入，形状为训练集数据的形状
    inputs_lstm = Input(shape=(x_train.shape[1], x_train.shape[2]))

    # 这里定义lstm层的输入（如果为第一层lstm层，则将初始化的input输入，如果不是第一层，则接受上一层输出的结果）
    for i in range(lstm_layers):
        if i == 0:
            inputs = inputs_lstm
        else:
            inputs = lstm_name[i - 1]
        if i == lstm_layers - 1:
            sequences_state = False
        else:
            sequences_state = True
        # 通过循环，我们将每层lstm的参数都设计完成
        lstm_name[i] = lstm_mode(inputs, lstm_units[i], sequences_state=sequences_state)

    # 同理设计全连接层神经网络的参数
    for i in range(lstm_dense_layers):
        if i == 0:
            inputs = lstm_name[lstm_layers - 1]
        else:
            inputs = lstm_dense_name[i - 1]
        lstm_dense_name[i], lstm_dense_dropout_name[i] = dense_mode(inputs, dropout, units_num=lstm_dense_units[i])

    outputs_lstm = Dense(1)(lstm_dense_dropout_name[lstm_dense_layers - 1])
    # print("last_dense", outputs_lstm.shape)
    # 利用函数式调试神经网络，调用inputs和outputs之间的神经网络
    LSTM_model = tf.keras.Model(inputs=inputs_lstm, outputs=outputs_lstm)
    LSTM_model.compile(optimizer=optimizers.Adam(), loss='mean_squared_error', )
    # print("训练集形状", x_train.shape)

    history = LSTM_model.fit(x_train, y_train, batch_size=32, epochs=epochs, validation_split=0.2, verbose=1)
    # 验证模型,model.evaluate返回的值是一个数组，其中score[0]为loss,score[1]为准确度

    # 反归一化
    # scaler = MinMaxScaler(feature_range=(0, 1))
    # scaler.fit_transform(pd.DataFrame(test['Close'].values))
    closing_price = LSTM_model.predict(x_test)
    
    # closing_price = scaler.inverse_transform(closing_price)
    # y_valid = scaler.inverse_transform([y_test])
    # acc
    acc = transncomp(closing_price, y_test)

    # 保存最优模型，并用最优模型的参数设置代替下一代最弱参数
    if acc > best_model_result:
        best_model_result = acc
        LSTM_model.save("AGA_"+stock_name+'.h5')

    # 原始的并没有保存模型
    return acc


# 设置遗传算法的参数
DNA_size = 2
DNA_size_max = 8  # 每条染色体的长度
POP_size = 50  # 种群数量
CROSS_RATE = 0.5  # 交叉率
MUTATION_RATE = 0.01  # 变异率
N_GENERATIONS = 50  # 迭代次数

Pc1 = 0.9  # 自适应交叉概率1
Pc2 = 0.6  # 自适应交叉概率2
Pm1 = 0.1  # 自适应变异概率1
Pm2 = 0.5  # 自适应变异概率2


# 定义适用度函数，即aim_function函数，接收返回值
def get_fitness(x):
    return aim_function(x_train, y_train, x_test, y_test, num=x)


# 生成新的种群
def select(pop, fitness):
    # 这里主要是进行选择操作，即从20个种群中随机选取重复随机采样出20个种群进行种群初始化操作，p代表被选择的概率，这里采用的是轮盘赌的方式
    idx = np.random.choice(np.arange(POP_size), size=POP_size, replace=True, p=fitness / fitness.sum())
    # 将选择的种群组成初始种群pop
    return pop[idx]


# 交叉函数
def crossover(parent, pop, cross_rate):
    # 这里主要进行交叉操作，随机数小于交叉概率则发生交叉
    if np.random.rand() < cross_rate:
        # 从20个种群中选择一个种群进行交叉
        i_ = np.random.randint(0, POP_size, size=1)  # 染色体的序号
        # 这里将生成一个8维的2进制数，并转换层成bool类型，true表示该位置交叉，False表示不交叉
        cross_points = np.random.randint(0, 2, size=DNA_size_max).astype(np.bool)  # 用True、False表示是否置换

        # 这一部分主要是对针对不做变异的部分
        for i, point in enumerate(cross_points):
            '''
            第一部分这里是指该位点为神经元个数的位点，本来该交换，但其中位点为0,末尾的0位置就
            不应该交叉，因为交叉完后,会对前两位的参数产生影响。

            第二部分即对前两位不进行交叉操作，因为前两位代表的是层数，层数交叉后会对神经元的个数产生影响
            '''
            # 第一部分
            if point == True and pop[i_, i] * parent[i] == 0:
                cross_points[i] = False
            # 第二部分
            if point == True and i < 2:
                cross_points[i] = False
        # 将第i_条染色体上对应位置的基因置换到parent染色体上
        parent[cross_points] = pop[i_, cross_points]
    return parent


# 定义变异函数
def mutate(child, mutate_rate):
    # mutate - k2 = 0.5 k4 = 0.5

    # 变异操作也只是针对后6位参数
    for point in range(DNA_size_max):
        if np.random.rand() < mutate_rate * 0.5:
            # 2位参数之后的参数才参与变异
            if (point >= 2) and (point < len(child) - 2):
                if child[point] != 0:
                    child[point] = np.random.randint(32, 128)
            if point == len(child) - 2:
                child[point] = np.random.randint(1, 5) / 10
            if point == len(child) - 1:
                child[point] = np.random.randint(1, 3)
    return child

def go():
    global best_model_result
    global best_gene
    best_model_result = 0
    best_gene = []  # 初始化一个保存最优参数组合的列表
    # 在数组中保存每轮最优，输出数据
    best = []
    best.append(0)
    pop_pop = [] # 记录一个列表保存参数和适应度 画热力图
    # 初始化2列层数参数
    pop_layers = np.zeros((POP_size, DNA_size), np.int32)
    pop_layers[:, 0] = np.random.randint(1, 3, size=(POP_size,))  # change 4
    pop_layers[:, 1] = np.random.randint(1, 3, size=(POP_size,))

    # 种群
    # 初始化20x8的种群
    pop = np.zeros((POP_size, DNA_size_max))
    # 将初始化的种群赋值，前两列为层数参数，后6列为神经元个数参数
    for i in range(POP_size):
        # 随机从[32,256]中抽取随机数组组成神经元个数信息
        pop_neurons = np.random.randint(32, 128, size=(pop_layers[i].sum(),))
        # 将2列层数信息和6列神经元个数信息合并乘8维种群信息
        pop_stack = np.hstack((pop_layers[i], pop_neurons))
        # 将这些信息赋值给pop种群进行初始化种群
        for j, gene in enumerate(pop_stack):
            pop[i][j] = gene

    # 在迭代次数内，计算种群的适应度函数
    for each_generation in range(N_GENERATIONS):
        # 初始化适应度
        fitness = np.zeros([POP_size, ])
        # 遍历20个种群，对基因进行操作
        for i in range(POP_size):
            # 第i个染色体上的基因
            pop_list = list(pop[i])
            pop_copy = np.array(pop_list).copy()
            # 对赋值为0的基因进行删除
            for j, each in enumerate(pop_list):
                if each == 0.0:
                    index = j
                    pop_list = pop_list[:j]
            # 将基因进行转换为int类型
            for k, each in enumerate(pop_list):
                each_int = int(each)
                pop_list[k] = each_int
            # 将计算出来的适应度填写在适应度数组中

            # test1 add dropout and epochs
            pop_list.append(random.randint(1, 5) / 10)
            pop_list.append(random.randint(1, 3))

            fitness[i] = get_fitness(pop_list)
            # 输出结果
            print('第%d代第%d个染色体的适应度为%f' % (each_generation + 1, i + 1, fitness[i]))
            print('此染色体为：', pop_list)
            pop_copy = pop_copy.tolist()
            pop_copy.append(fitness[i])
            pop_pop.append(pop_copy)

        # 创建最优模型
        print('Generation:', each_generation + 1, 'Most fitted DNA:', pop[np.argmax(fitness), :], '适应度为：',
            fitness[np.argmax(fitness)])
        # 记录每代最好值，如果当代不如上一代，则替换
        best.append(best_model_result)
        if best_model_result > best[-2] or len(best_gene) == 1:
            best_gene = []
            for i in range(DNA_size_max):
                best_gene.append(pop[np.argmax(fitness), :][i])
        else:
            if best_model_result < best[-2] and each_generation > 20:
                pop[np.argmin(fitness), :] = [i for i in best_gene]
                fitness[np.argmin(fitness)] = best_model_result

        # 计算自适应概率,这里可以采用序优化的方法，形成sns-aga
        # 产生一个带有适应度值和平均值的新列表
        fitness_new = list(fitness)
        fitness_new.append(np.mean(fitness))
        fitness_new.sort()
        # 获取序号
        for j in range(POP_size + 1):
            if fitness_new[j] == np.mean(fitness):
                N2 = j + 1
        N3 = len(fitness_new)
        index_array = []
        cross_rate = []
        mutate_rate = []

        for i in fitness_new:
            if i >= np.mean(fitness):
                index_array.append(0)
            else:
                index_array.append(1)

        # cross - Pc1 Pc2
        for i in range(POP_size + 1):
            if index_array[i] == 0:
                cross_rate.append(np.reciprocal(((Pc1 - Pc2) + np.exp((i + 1 - N2) / (N3 - N2))) * Pc1))
            else:
                cross_rate.append(0.9)
        del (cross_rate[N2])
        # mutate - Pm1 Pm2
        for i in range(POP_size):
            if index_array[i] == 0:
                mutate_rate.append(np.reciprocal(((Pm1 - Pm2) + np.exp((i + 1 - N2) / (N3 - N2))) * Pm1))
            else:
                mutate_rate.append(0.09)

        # 生成新的种群
        pop = select(pop, fitness)
        # 复制一遍种群
        pop_copy = pop.copy()
        # 遍历pop中的每一个种群，进行交叉，变异，遗传操作
        index = 0
        for parent in pop:
            child = crossover(parent, pop_copy, cross_rate[index])
            child = mutate(child, mutate_rate[index])
            parent = child
            index += 1

    print(best)
    # 需要保存的数据
    csv1 = pd.DataFrame(best)
    csv1 = csv1.to_csv("AGA_"+stock_name+"_result.csv")

    csv2 = pd.DataFrame(pop_pop)
    csv2 = csv2.to_csv("AGA_"+stock_name+"_pop.csv")


for key,value in stock_list.items():
    print (key,"------------",value)
    stock_name = key
    s_length = value
    x_train, x_test, y_train, y_test = load_data()
    go()
# Out:
# Apple ------------ 3400
# Epoch 1/2
# 85/85 [==============================] - 7s 50ms/step - loss: 0.0975 - val_loss: 0.0627
# Epoch 2/2
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0412 - val_loss: 0.0370
# 第1代第1个染色体的适应度为0.801619
# 此染色体为： [2, 2, 49, 72, 36, 116, 0.2, 2]
# Epoch 1/3
# 85/85 [==============================] - 3s 19ms/step - loss: 0.0624 - val_loss: 0.0418
# Epoch 2/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0334 - val_loss: 0.0284
# Epoch 3/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0187 - val_loss: 0.0153
# 第1代第2个染色体的适应度为0.810729
# 此染色体为： [1, 1, 93, 42, 0.2, 3]
# Epoch 1/2
# 85/85 [==============================] - 5s 29ms/step - loss: 0.0686 - val_loss: 0.0497
# Epoch 2/2
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0322 - val_loss: 0.0262
# 第1代第3个染色体的适应度为0.849190
# 此染色体为： [2, 1, 70, 40, 112, 0.3, 2]
# Epoch 1/2
# 85/85 [==============================] - 3s 15ms/step - loss: 0.1617 - val_loss: 0.0893
# Epoch 2/2
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0707 - val_loss: 0.0390
# 第1代第4个染色体的适应度为0.774291
# 此染色体为： [1, 2, 57, 99, 108, 0.3, 2]
# Epoch 1/2
# 85/85 [==============================] - 5s 29ms/step - loss: 0.0548 - val_loss: 0.0368
# Epoch 2/2
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0240 - val_loss: 0.0183
# 第1代第5个染色体的适应度为0.851215
# 此染色体为： [2, 1, 73, 44, 80, 0.1, 2]
# Epoch 1/3
# 85/85 [==============================] - 3s 13ms/step - loss: 0.0598 - val_loss: 0.0375
# Epoch 2/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0302 - val_loss: 0.0327
# Epoch 3/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0209 - val_loss: 0.0243
# 第1代第6个染色体的适应度为0.792510
# 此染色体为： [1, 1, 36, 50, 0.3, 3]
# Epoch 1/3
# 85/85 [==============================] - 6s 42ms/step - loss: 0.1297 - val_loss: 0.0743
# Epoch 2/3
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0533 - val_loss: 0.0325
# Epoch 3/3
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0204 - val_loss: 0.0183
# 第1代第7个染色体的适应度为0.851215
# 此染色体为： [2, 2, 122, 116, 52, 110, 0.5, 3]
# 85/85 [==============================] - 3s 25ms/step - loss: 0.0517 - val_loss: 0.0332
# 第1代第8个染色体的适应度为0.800607
# 此染色体为： [1, 1, 95, 36, 0.5, 1]
# Epoch 1/2
# 85/85 [==============================] - 6s 39ms/step - loss: 0.0584 - val_loss: 0.0348
# Epoch 2/2
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0249 - val_loss: 0.0212
# 第1代第9个染色体的适应度为0.738866
# 此染色体为： [2, 1, 65, 116, 38, 0.5, 2]
# Epoch 1/2
# 85/85 [==============================] - 6s 41ms/step - loss: 0.1098 - val_loss: 0.0675
# Epoch 2/2
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0544 - val_loss: 0.0405
# 第1代第10个染色体的适应度为0.834008
# 此染色体为： [2, 2, 80, 121, 41, 62, 0.5, 2]
# 85/85 [==============================] - 3s 20ms/step - loss: 0.0830 - val_loss: 0.0467
# 第1代第11个染色体的适应度为0.763158
# 此染色体为： [1, 1, 108, 78, 0.1, 1]
# Epoch 1/3
# 85/85 [==============================] - 6s 38ms/step - loss: 0.0777 - val_loss: 0.0432
# Epoch 2/3
# 85/85 [==============================] - 2s 28ms/step - loss: 0.0313 - val_loss: 0.0320
# Epoch 3/3
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0125 - val_loss: 0.0115
# 第1代第12个染色体的适应度为0.838057
# 此染色体为： [2, 1, 96, 124, 60, 0.4, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 19ms/step - loss: 0.1453 - val_loss: 0.0859
# Epoch 2/3
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0696 - val_loss: 0.0528
# Epoch 3/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0323 - val_loss: 0.0328
# 第1代第13个染色体的适应度为0.854251
# 此染色体为： [1, 2, 114, 61, 92, 0.5, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 21ms/step - loss: 0.1088 - val_loss: 0.0580
# Epoch 2/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0459 - val_loss: 0.0257
# Epoch 3/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0192 - val_loss: 0.0128
# 第1代第14个染色体的适应度为0.856275
# 此染色体为： [1, 1, 116, 109, 0.5, 3]
# Epoch 1/2
# 85/85 [==============================] - 5s 28ms/step - loss: 0.0517 - val_loss: 0.0344
# Epoch 2/2
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0228 - val_loss: 0.0192
# 第1代第15个染色体的适应度为0.848178
# 此染色体为： [2, 1, 99, 37, 83, 0.3, 2]
# 85/85 [==============================] - 3s 17ms/step - loss: 0.0691 - val_loss: 0.0397
# 第1代第16个染色体的适应度为0.757085
# 此染色体为： [1, 1, 91, 63, 0.1, 1]
# Epoch 1/3
# 85/85 [==============================] - 5s 31ms/step - loss: 0.0867 - val_loss: 0.0468
# Epoch 2/3
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0331 - val_loss: 0.0198
# Epoch 3/3
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0126 - val_loss: 0.0172
# 第1代第17个染色体的适应度为0.851215
# 此染色体为： [2, 1, 83, 98, 84, 0.5, 3]
# 85/85 [==============================] - 3s 17ms/step - loss: 0.0588 - val_loss: 0.0389
# 第1代第18个染色体的适应度为0.802632
# 此染色体为： [1, 1, 75, 43, 0.4, 1]
# 85/85 [==============================] - 5s 29ms/step - loss: 0.0930 - val_loss: 0.0425
# 第1代第19个染色体的适应度为0.816802
# 此染色体为： [2, 1, 40, 125, 97, 0.1, 1]
# Epoch 1/3
# 85/85 [==============================] - 5s 32ms/step - loss: 0.0549 - val_loss: 0.0323
# Epoch 2/3
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0221 - val_loss: 0.0162
# Epoch 3/3
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0087 - val_loss: 0.0125
# 第1代第20个染色体的适应度为0.842105
# 此染色体为： [2, 1, 90, 102, 42, 0.2, 3]
# Epoch 1/3
# 85/85 [==============================] - 2s 15ms/step - loss: 0.1466 - val_loss: 0.0780
# Epoch 2/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0585 - val_loss: 0.0342
# Epoch 3/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0208 - val_loss: 0.0251
# 第1代第21个染色体的适应度为0.839069
# 此染色体为： [1, 2, 48, 103, 96, 0.1, 3]
# 85/85 [==============================] - 2s 12ms/step - loss: 0.1005 - val_loss: 0.0692
# 第1代第22个染色体的适应度为0.711538
# 此染色体为： [1, 2, 44, 67, 34, 0.3, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 20ms/step - loss: 0.1159 - val_loss: 0.0606
# Epoch 2/2
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0454 - val_loss: 0.0251
# 第1代第23个染色体的适应度为0.779352
# 此染色体为： [1, 1, 125, 121, 0.4, 2]
# 85/85 [==============================] - 5s 35ms/step - loss: 0.0840 - val_loss: 0.0451
# 第1代第24个染色体的适应度为0.837045
# 此染色体为： [2, 1, 110, 79, 109, 0.1, 1]
# Epoch 1/3
# 85/85 [==============================] - 4s 21ms/step - loss: 0.0815 - val_loss: 0.0492
# Epoch 2/3
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0416 - val_loss: 0.0305
# Epoch 3/3
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0240 - val_loss: 0.0210
# 第1代第25个染色体的适应度为0.856275
# 此染色体为： [1, 1, 125, 54, 0.5, 3]
# Epoch 1/3
# 85/85 [==============================] - 5s 31ms/step - loss: 0.1525 - val_loss: 0.0785
# Epoch 2/3
# 85/85 [==============================] - 2s 20ms/step - loss: 0.0563 - val_loss: 0.0304
# Epoch 3/3
# 85/85 [==============================] - 2s 20ms/step - loss: 0.0192 - val_loss: 0.0264
# 第1代第26个染色体的适应度为0.838057
# 此染色体为： [2, 2, 72, 80, 115, 60, 0.5, 3]
# 85/85 [==============================] - 2s 12ms/step - loss: 0.1135 - val_loss: 0.0726
# 第1代第27个染色体的适应度为0.754049
# 此染色体为： [1, 2, 42, 50, 98, 0.2, 1]
# 85/85 [==============================] - 2s 12ms/step - loss: 0.1245 - val_loss: 0.0792
# 第1代第28个染色体的适应度为0.841093
# 此染色体为： [1, 2, 48, 117, 38, 0.2, 1]
# 85/85 [==============================] - 2s 13ms/step - loss: 0.0651 - val_loss: 0.0404
# 第1代第29个染色体的适应度为0.706478
# 此染色体为： [1, 1, 42, 82, 0.5, 1]
# Epoch 1/3
# 85/85 [==============================] - 5s 31ms/step - loss: 0.1243 - val_loss: 0.0765
# Epoch 2/3
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0567 - val_loss: 0.0528
# Epoch 3/3
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0247 - val_loss: 0.0365
# 第1代第30个染色体的适应度为0.838057
# 此染色体为： [2, 2, 123, 55, 67, 74, 0.5, 3]
# Epoch 1/2
# 85/85 [==============================] - 5s 30ms/step - loss: 0.1027 - val_loss: 0.0645
# Epoch 2/2
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0477 - val_loss: 0.0431
# 第1代第31个染色体的适应度为0.819838
# 此染色体为： [2, 2, 121, 51, 44, 85, 0.4, 2]
# Epoch 1/3
# 85/85 [==============================] - 2s 13ms/step - loss: 0.0683 - val_loss: 0.0367
# Epoch 2/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0319 - val_loss: 0.0273
# Epoch 3/3
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0231 - val_loss: 0.0227
# 第1代第32个染色体的适应度为0.839069
# 此染色体为： [1, 1, 44, 39, 0.4, 3]
# 85/85 [==============================] - 3s 17ms/step - loss: 0.0553 - val_loss: 0.0371
# 第1代第33个染色体的适应度为0.821862
# 此染色体为： [1, 1, 103, 32, 0.1, 1]
# 85/85 [==============================] - 2s 12ms/step - loss: 0.0928 - val_loss: 0.0694
# 第1代第34个染色体的适应度为0.821862
# 此染色体为： [1, 2, 33, 77, 33, 0.2, 1]
# Epoch 1/3
# 85/85 [==============================] - 3s 19ms/step - loss: 0.0884 - val_loss: 0.0485
# Epoch 2/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0344 - val_loss: 0.0191
# Epoch 3/3
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0119 - val_loss: 0.0082
# 第1代第35个染色体的适应度为0.856275
# 此染色体为： [1, 1, 85, 112, 0.2, 3]
# Epoch 1/3
# 85/85 [==============================] - 6s 41ms/step - loss: 0.0946 - val_loss: 0.0528
# Epoch 2/3
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0387 - val_loss: 0.0242
# Epoch 3/3
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0150 - val_loss: 0.0126
# 第1代第36个染色体的适应度为0.837045
# 此染色体为： [2, 1, 125, 87, 114, 0.2, 3]
# 85/85 [==============================] - 3s 15ms/step - loss: 0.1252 - val_loss: 0.0927
# 第1代第37个染色体的适应度为0.785425
# 此染色体为： [1, 2, 41, 104, 50, 0.2, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 14ms/step - loss: 0.0629 - val_loss: 0.0405
# Epoch 2/2
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0321 - val_loss: 0.0244
# 第1代第38个染色体的适应度为0.794534
# 此染色体为： [1, 1, 43, 79, 0.5, 2]
# 85/85 [==============================] - 5s 34ms/step - loss: 0.0718 - val_loss: 0.0457
# 第1代第39个染色体的适应度为0.842105
# 此染色体为： [2, 1, 112, 71, 75, 0.1, 1]
# 85/85 [==============================] - 3s 18ms/step - loss: 0.1525 - val_loss: 0.0747
# 第1代第40个染色体的适应度为0.767206
# 此染色体为： [1, 2, 58, 107, 101, 0.2, 1]
# Epoch 1/3
# 85/85 [==============================] - 3s 16ms/step - loss: 0.0914 - val_loss: 0.0624
# Epoch 2/3
# 85/85 [==============================] - 1s 11ms/step - loss: 0.0506 - val_loss: 0.0398
# Epoch 3/3
# 85/85 [==============================] - 1s 12ms/step - loss: 0.0284 - val_loss: 0.0298
# 第1代第41个染色体的适应度为0.823887
# 此染色体为： [1, 2, 62, 34, 74, 0.1, 3]
# Epoch 1/3
# 85/85 [==============================] - 6s 38ms/step - loss: 0.0476 - val_loss: 0.0316
# Epoch 2/3
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0240 - val_loss: 0.0197
# Epoch 3/3
# 85/85 [==============================] - 2s 21ms/step - loss: 0.0133 - val_loss: 0.0171
# 第1代第42个染色体的适应度为0.842105
# 此染色体为： [2, 1, 123, 39, 50, 0.5, 3]
# Epoch 1/3
# 85/85 [==============================] - 5s 29ms/step - loss: 0.0451 - val_loss: 0.0329
# Epoch 2/3
# 85/85 [==============================] - 2s 21ms/step - loss: 0.0217 - val_loss: 0.0223
# Epoch 3/3
# 85/85 [==============================] - 2s 21ms/step - loss: 0.0108 - val_loss: 0.0167
# 第1代第43个染色体的适应度为0.852227
# 此染色体为： [2, 1, 125, 33, 63, 0.1, 3]
# Epoch 1/3
# 85/85 [==============================] - 5s 36ms/step - loss: 0.0753 - val_loss: 0.0444
# Epoch 2/3
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0304 - val_loss: 0.0203
# Epoch 3/3
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0121 - val_loss: 0.0136
# 第1代第44个染色体的适应度为0.853239
# 此染色体为： [2, 1, 87, 90, 69, 0.2, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 19ms/step - loss: 0.1510 - val_loss: 0.0904
# Epoch 2/3
# 85/85 [==============================] - 1s 12ms/step - loss: 0.0732 - val_loss: 0.0436
# Epoch 3/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0332 - val_loss: 0.0225
# 第1代第45个染色体的适应度为0.850202
# 此染色体为： [1, 2, 97, 84, 67, 0.2, 3]
# Epoch 1/3
# 85/85 [==============================] - 7s 53ms/step - loss: 0.1906 - val_loss: 0.0871
# Epoch 2/3
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0573 - val_loss: 0.0328
# Epoch 3/3
# 85/85 [==============================] - 3s 30ms/step - loss: 0.0151 - val_loss: 0.0236
# 第1代第46个染色体的适应度为0.848178
# 此染色体为： [2, 2, 122, 124, 107, 124, 0.2, 3]
# 85/85 [==============================] - 5s 30ms/step - loss: 0.0436 - val_loss: 0.0304
# 第1代第47个染色体的适应度为0.809717
# 此染色体为： [2, 1, 126, 36, 65, 0.2, 1]
# Epoch 1/3
# 85/85 [==============================] - 6s 40ms/step - loss: 0.0804 - val_loss: 0.0442
# Epoch 2/3
# 85/85 [==============================] - 4s 41ms/step - loss: 0.0280 - val_loss: 0.0162
# Epoch 3/3
# 85/85 [==============================] - 2s 29ms/step - loss: 0.0091 - val_loss: 0.0130
# 第1代第48个染色体的适应度为0.828947
# 此染色体为： [2, 1, 103, 124, 72, 0.3, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 13ms/step - loss: 0.0649 - val_loss: 0.0412
# Epoch 2/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0325 - val_loss: 0.0240
# Epoch 3/3
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0177 - val_loss: 0.0157
# 第1代第49个染色体的适应度为0.805668
# 此染色体为： [1, 1, 41, 100, 0.2, 3]
# Epoch 1/2
# 85/85 [==============================] - 3s 20ms/step - loss: 0.0897 - val_loss: 0.0601
# Epoch 2/2
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0484 - val_loss: 0.0345
# 第1代第50个染色体的适应度为0.855263
# 此染色体为： [1, 2, 95, 35, 55, 0.1, 2]
# Generation: 1 Most fitted DNA: [  1.   1. 116. 109.   0.   0.   0.   0.] 适应度为： 0.8562753036437247
# Epoch 1/2
# 85/85 [==============================] - 3s 23ms/step - loss: 0.0816 - val_loss: 0.0515
# Epoch 2/2
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0410 - val_loss: 0.0278
# 第2代第1个染色体的适应度为0.782389
# 此染色体为： [1, 1, 123, 55, 0.5, 2]
# Epoch 1/3
# 85/85 [==============================] - 3s 19ms/step - loss: 0.0920 - val_loss: 0.0600
# Epoch 2/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0462 - val_loss: 0.0314
# Epoch 3/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0224 - val_loss: 0.0251
# 第2代第2个染色体的适应度为0.855263
# 此染色体为： [1, 2, 90, 34, 74, 0.2, 3]
# Epoch 1/2
# 85/85 [==============================] - 5s 30ms/step - loss: 0.0726 - val_loss: 0.0395
# Epoch 2/2
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0289 - val_loss: 0.0193
# 第2代第3个染色体的适应度为0.849190
# 此染色体为： [2, 1, 112, 71, 75, 0.5, 2]
# 第2代第4个染色体的适应度为0.761134
# 此染色体为： [2, 2, 49, 72, 101, 116, 0, 0.2, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 14ms/step - loss: 0.1602 - val_loss: 0.0883
# Epoch 2/2
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0664 - val_loss: 0.0363
# 第2代第5个染色体的适应度为0.805668
# 此染色体为： [1, 2, 57, 99, 108, 0.4, 2]
# Epoch 1/2
# 85/85 [==============================] - 2s 12ms/step - loss: 0.0645 - val_loss: 0.0420
# Epoch 2/2
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0322 - val_loss: 0.0303
# 第2代第6个染色体的适应度为0.744939
# 此染色体为： [1, 1, 44, 39, 0.3, 2]
# Epoch 1/3
# 85/85 [==============================] - 5s 26ms/step - loss: 0.0534 - val_loss: 0.0326
# Epoch 2/3
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0243 - val_loss: 0.0234
# Epoch 3/3
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0130 - val_loss: 0.0164
# 第2代第7个染色体的适应度为0.829960
# 此染色体为： [2, 1, 33, 77, 33, 0.5, 3]
# 85/85 [==============================] - 3s 14ms/step - loss: 0.1035 - val_loss: 0.0643
# 第2代第8个染色体的适应度为0.738866
# 此染色体为： [1, 2, 42, 50, 98, 0.2, 1]
# 85/85 [==============================] - 3s 18ms/step - loss: 0.0948 - val_loss: 0.0504
# 第2代第9个染色体的适应度为0.782389
# 此染色体为： [1, 1, 85, 112, 0.5, 1]
# Epoch 1/2
# 85/85 [==============================] - 5s 36ms/step - loss: 0.0934 - val_loss: 0.0446
# Epoch 2/2
# 85/85 [==============================] - 3s 31ms/step - loss: 0.0277 - val_loss: 0.0175
# 第2代第10个染色体的适应度为0.849190
# 此染色体为： [2, 1, 95, 125, 97, 0.1, 2]
# 85/85 [==============================] - 5s 36ms/step - loss: 0.0904 - val_loss: 0.0507
# 第2代第11个染色体的适应度为0.826923
# 此染色体为： [2, 1, 110, 79, 109, 0.4, 1]
# Epoch 1/2
# 85/85 [==============================] - 5s 31ms/step - loss: 0.1217 - val_loss: 0.0921
# Epoch 2/2
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0586 - val_loss: 0.0419
# 第2代第12个染色体的适应度为0.837045
# 此染色体为： [2, 2, 123, 55, 67, 74, 0.5, 2]
# 85/85 [==============================] - 3s 16ms/step - loss: 0.0768 - val_loss: 0.0442
# 第2代第13个染色体的适应度为0.806680
# 此染色体为： [1, 1, 57, 99, 0.5, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 18ms/step - loss: 0.0897 - val_loss: 0.0491
# Epoch 2/2
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0373 - val_loss: 0.0223
# 第2代第14个染色体的适应度为0.774291
# 此染色体为： [1, 1, 90, 102, 0.5, 2]
# Epoch 1/3
# 85/85 [==============================] - 4s 22ms/step - loss: 0.0607 - val_loss: 0.0402
# Epoch 2/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0302 - val_loss: 0.0271
# Epoch 3/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0171 - val_loss: 0.0202
# 第2代第15个染色体的适应度为0.825911
# 此染色体为： [2, 1, 44, 39, 69, 0.2, 3]
# Epoch 1/2
# 85/85 [==============================] - 2s 11ms/step - loss: 0.1322 - val_loss: 0.0838
# Epoch 2/2
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0648 - val_loss: 0.0405
# 第2代第16个染色体的适应度为0.822874
# 此染色体为： [1, 2, 40, 77, 97, 0.2, 2]
# Epoch 1/3
# 85/85 [==============================] - 2s 13ms/step - loss: 0.0432 - val_loss: 0.0303
# Epoch 2/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0230 - val_loss: 0.0169
# Epoch 3/3
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0118 - val_loss: 0.0116
# 第2代第17个染色体的适应度为0.853239
# 此染色体为： [1, 1, 62, 34, 0.1, 3]
# Epoch 1/2
# 85/85 [==============================] - 2s 14ms/step - loss: 0.0996 - val_loss: 0.0714
# Epoch 2/2
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0591 - val_loss: 0.0460
# 第2代第18个染色体的适应度为0.830972
# 此染色体为： [1, 2, 42, 50, 50, 0.5, 2]
# 85/85 [==============================] - 3s 16ms/step - loss: 0.0888 - val_loss: 0.0477
# 第2代第19个染色体的适应度为0.805668
# 此染色体为： [1, 1, 85, 112, 0.2, 1]
# 85/85 [==============================] - 5s 35ms/step - loss: 0.0870 - val_loss: 0.0395
# 第2代第20个染色体的适应度为0.808704
# 此染色体为： [2, 1, 101, 121, 89, 0.1, 1]
# 85/85 [==============================] - 5s 32ms/step - loss: 0.0761 - val_loss: 0.0406
# 第2代第21个染色体的适应度为0.818826
# 此染色体为： [2, 1, 122, 68, 106, 0.2, 1]
# Epoch 1/3
# 85/85 [==============================] - 3s 18ms/step - loss: 0.0882 - val_loss: 0.0597
# Epoch 2/3
# 85/85 [==============================] - 1s 18ms/step - loss: 0.0447 - val_loss: 0.0342
# Epoch 3/3
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0221 - val_loss: 0.0247
# 第2代第22个染色体的适应度为0.846154
# 此染色体为： [1, 2, 108, 33, 52, 0.4, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 18ms/step - loss: 0.1282 - val_loss: 0.0948
# Epoch 2/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0778 - val_loss: 0.0589
# Epoch 3/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0488 - val_loss: 0.0464
# 第2代第23个染色体的适应度为0.791498
# 此染色体为： [1, 2, 91, 57, 41, 0.5, 3]
# Epoch 1/2
# 85/85 [==============================] - 5s 27ms/step - loss: 0.1412 - val_loss: 0.0719
# Epoch 2/2
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0466 - val_loss: 0.0386
# 第2代第24个染色体的适应度为0.842105
# 此染色体为： [2, 2, 69, 46, 96, 116, 0, 2, 0.2, 3]
# 85/85 [==============================] - 5s 30ms/step - loss: 0.0878 - val_loss: 0.0562
# 第2代第25个染色体的适应度为0.798583
# 此染色体为： [2, 2, 77, 35, 44, 80, 0, 1, 0.4, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 13ms/step - loss: 0.0636 - val_loss: 0.0404
# Epoch 2/2
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0285 - val_loss: 0.0207
# 第2代第26个染色体的适应度为0.797571
# 此染色体为： [1, 1, 54, 78, 0.1, 2]
# 85/85 [==============================] - 3s 19ms/step - loss: 0.1011 - val_loss: 0.0577
# 第2代第27个染色体的适应度为0.851215
# 此染色体为： [1, 2, 107, 36, 114, 0.1, 1]
# Epoch 1/3
# 85/85 [==============================] - 4s 27ms/step - loss: 0.0497 - val_loss: 0.0334
# Epoch 2/3
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0248 - val_loss: 0.0231
# Epoch 3/3
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0143 - val_loss: 0.0160
# 第2代第28个染色体的适应度为0.854251
# 此染色体为： [2, 1, 58, 48, 37, 0.3, 3]
# Epoch 1/3
# 85/85 [==============================] - 5s 28ms/step - loss: 0.0504 - val_loss: 0.0371
# Epoch 2/3
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0217 - val_loss: 0.0209
# Epoch 3/3
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0094 - val_loss: 0.0124
# 第2代第29个染色体的适应度为0.843117
# 此染色体为： [2, 1, 109, 32, 127, 0.5, 3]
# Epoch 1/3
# 85/85 [==============================] - 2s 14ms/step - loss: 0.1395 - val_loss: 0.0811
# Epoch 2/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0624 - val_loss: 0.0374
# Epoch 3/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0258 - val_loss: 0.0249
# 第2代第30个染色体的适应度为0.851215
# 此染色体为： [1, 2, 52, 77, 116, 0.4, 3]
# Epoch 1/2
# 85/85 [==============================] - 3s 20ms/step - loss: 0.0761 - val_loss: 0.0397
# Epoch 2/2
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0299 - val_loss: 0.0184
# 第2代第31个染色体的适应度为0.776316
# 此染色体为： [1, 1, 123, 61, 0.4, 2]
# Epoch 1/3
# 85/85 [==============================] - 5s 26ms/step - loss: 0.0618 - val_loss: 0.0351
# Epoch 2/3
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0243 - val_loss: 0.0166
# Epoch 3/3
# 85/85 [==============================] - 2s 20ms/step - loss: 0.0087 - val_loss: 0.0111
# 第2代第32个染色体的适应度为0.854251
# 此染色体为： [2, 1, 92, 48, 102, 0.3, 3]
# 85/85 [==============================] - 3s 17ms/step - loss: 0.0607 - val_loss: 0.0410
# 第2代第33个染色体的适应度为0.855263
# 此染色体为： [1, 1, 91, 46, 0.3, 1]
# Epoch 1/2
# 85/85 [==============================] - 4s 22ms/step - loss: 0.0620 - val_loss: 0.0384
# Epoch 2/2
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0284 - val_loss: 0.0205
# 第2代第34个染色体的适应度为0.852227
# 此染色体为： [2, 1, 47, 45, 93, 0.5, 2]
# Epoch 1/3
# 85/85 [==============================] - 5s 31ms/step - loss: 0.0611 - val_loss: 0.0410
# Epoch 2/3
# 85/85 [==============================] - 2s 21ms/step - loss: 0.0284 - val_loss: 0.0244
# Epoch 3/3
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0132 - val_loss: 0.0155
# 第2代第35个染色体的适应度为0.854251
# 此染色体为： [2, 1, 122, 52, 74, 0.1, 3]
# 85/85 [==============================] - 5s 29ms/step - loss: 0.1130 - val_loss: 0.0609
# 第2代第36个染色体的适应度为0.838057
# 此染色体为： [2, 2, 37, 99, 47, 108, 0, 1, 0.4, 3]
# 85/85 [==============================] - 4s 18ms/step - loss: 0.1346 - val_loss: 0.0810
# 第2代第37个染色体的适应度为0.655870
# 此染色体为： [1, 2, 76, 99, 38, 0.3, 1]
# Epoch 1/3
# 85/85 [==============================] - 3s 26ms/step - loss: 0.0945 - val_loss: 0.0393
# Epoch 2/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0266 - val_loss: 0.0120
# Epoch 3/3
# 85/85 [==============================] - 1s 12ms/step - loss: 0.0063 - val_loss: 0.0063
# 第2代第38个染色体的适应度为0.856275
# 此染色体为： [1, 1, 106, 125, 0.1, 3]
# Epoch 1/2
# 85/85 [==============================] - 3s 13ms/step - loss: 0.1712 - val_loss: 0.0829
# Epoch 2/2
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0604 - val_loss: 0.0319
# 第2代第39个染色体的适应度为0.811741
# 此染色体为： [1, 2, 54, 123, 115, 0.3, 2]
# Epoch 1/2
# 85/85 [==============================] - 5s 29ms/step - loss: 0.1263 - val_loss: 0.0754
# Epoch 2/2
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0529 - val_loss: 0.0438
# 第2代第40个染色体的适应度为0.844130
# 此染色体为： [2, 2, 93, 66, 57, 114, 0, 2, 0.4, 3]
# 85/85 [==============================] - 3s 22ms/step - loss: 0.0574 - val_loss: 0.0358
# 第2代第41个染色体的适应度为0.708502
# 此染色体为： [1, 1, 121, 39, 0.1, 1]
# Epoch 1/3
# 85/85 [==============================] - 3s 18ms/step - loss: 0.0836 - val_loss: 0.0491
# Epoch 2/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0377 - val_loss: 0.0247
# Epoch 3/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0181 - val_loss: 0.0148
# 第2代第42个染色体的适应度为0.845142
# 此染色体为： [1, 1, 93, 76, 0.1, 3]
# Epoch 1/2
# 85/85 [==============================] - 2s 13ms/step - loss: 0.0550 - val_loss: 0.0344
# Epoch 2/2
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0266 - val_loss: 0.0178
# 第2代第43个染色体的适应度为0.848178
# 此染色体为： [1, 1, 53, 63, 0.1, 2]
# Epoch 1/3
# 85/85 [==============================] - 3s 22ms/step - loss: 0.0893 - val_loss: 0.0533
# Epoch 2/3
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0412 - val_loss: 0.0317
# Epoch 3/3
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0191 - val_loss: 0.0324
# 第2代第44个染色体的适应度为0.855263
# 此染色体为： [1, 2, 125, 35, 40, 0.2, 3]
# 85/85 [==============================] - 5s 33ms/step - loss: 0.1932 - val_loss: 0.0801
# 第2代第45个染色体的适应度为0.846154
# 此染色体为： [2, 2, 93, 108, 126, 120, 0, 1, 0.5, 3]
# 85/85 [==============================] - 5s 30ms/step - loss: 0.0771 - val_loss: 0.0424
# 第2代第46个染色体的适应度为0.840081
# 此染色体为： [2, 1, 75, 87, 72, 0.4, 1]
# 85/85 [==============================] - 2s 15ms/step - loss: 0.1878 - val_loss: 0.0980
# 第2代第47个染色体的适应度为0.846154
# 此染色体为： [1, 2, 76, 120, 118, 0.5, 1]
# Epoch 1/3
# 85/85 [==============================] - 4s 22ms/step - loss: 0.0447 - val_loss: 0.0298
# Epoch 2/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0166 - val_loss: 0.0198
# Epoch 3/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0059 - val_loss: 0.0179
# 第2代第48个染色体的适应度为0.843117
# 此染色体为： [2, 1, 44, 32, 94, 0.1, 3]
# Epoch 1/2
# 85/85 [==============================] - 2s 13ms/step - loss: 0.1313 - val_loss: 0.0807
# Epoch 2/2
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0673 - val_loss: 0.0461
# 第2代第49个染色体的适应度为0.725709
# 此染色体为： [1, 2, 51, 90, 57, 0.5, 2]
# Epoch 1/2
# 85/85 [==============================] - 5s 35ms/step - loss: 0.1442 - val_loss: 0.0701
# Epoch 2/2
# 85/85 [==============================] - 2s 28ms/step - loss: 0.0500 - val_loss: 0.0282
# 第2代第50个染色体的适应度为0.839069
# 此染色体为： [2, 2, 125, 112, 111, 35, 0, 2, 0.5, 2]
# Generation: 2 Most fitted DNA: [  1.    1.  106.  125.    0.    0.    0.2   1. ] 适应度为： 0.8562753036437247
# Epoch 1/3
# 85/85 [==============================] - 2s 13ms/step - loss: 0.0609 - val_loss: 0.0391
# Epoch 2/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0325 - val_loss: 0.0259
# Epoch 3/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0191 - val_loss: 0.0189
# 第3代第1个染色体的适应度为0.849190
# 此染色体为： [1, 1, 57, 55, 0.4, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 18ms/step - loss: 0.0795 - val_loss: 0.0489
# Epoch 2/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0395 - val_loss: 0.0270
# Epoch 3/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0204 - val_loss: 0.0186
# 第3代第2个染色体的适应度为0.848178
# 此染色体为： [1, 1, 123, 55, 0.2, 3]
# Epoch 1/2
# 85/85 [==============================] - 3s 18ms/step - loss: 0.0778 - val_loss: 0.0450
# Epoch 2/2
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0342 - val_loss: 0.0240
# 第3代第3个染色体的适应度为0.821862
# 此染色体为： [1, 1, 123, 55, 0.4, 2]
# 85/85 [==============================] - 5s 34ms/step - loss: 0.1444 - val_loss: 0.0740
# 第3代第4个染色体的适应度为0.831984
# 此染色体为： [2, 2, 93, 71, 75, 120, 0, 1, 0.2, 2]
# 85/85 [==============================] - 3s 13ms/step - loss: 0.0875 - val_loss: 0.0607
# 第3代第5个染色体的适应度为0.822874
# 此染色体为： [1, 2, 42, 34, 74, 0.1, 1]
# 85/85 [==============================] - 5s 29ms/step - loss: 0.1195 - val_loss: 0.0650
# 第3代第6个染色体的适应度为0.832996
# 此染色体为： [2, 2, 37, 112, 47, 108, 0, 1, 0.5, 3]
# Epoch 1/2
# 85/85 [==============================] - 6s 40ms/step - loss: 0.0551 - val_loss: 0.0325
# Epoch 2/2
# 85/85 [==============================] - 2s 20ms/step - loss: 0.0213 - val_loss: 0.0169
# 第3代第7个染色体的适应度为0.851215
# 此染色体为： [2, 1, 101, 46, 89, 0.3, 2]
# Epoch 1/2
# 85/85 [==============================] - 3s 13ms/step - loss: 0.0523 - val_loss: 0.0338
# Epoch 2/2
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0266 - val_loss: 0.0231
# 第3代第8个染色体的适应度为0.767206
# 此染色体为： [1, 1, 53, 40, 0.4, 2]
# Epoch 1/3
# 85/85 [==============================] - 2s 12ms/step - loss: 0.1456 - val_loss: 0.0930
# Epoch 2/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0776 - val_loss: 0.0520
# Epoch 3/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0433 - val_loss: 0.0328
# 第3代第9个染色体的适应度为0.858300
# 此染色体为： [1, 2, 40, 77, 97, 0.4, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 22ms/step - loss: 0.0548 - val_loss: 0.0313
# Epoch 2/3
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0235 - val_loss: 0.0152
# Epoch 3/3
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0100 - val_loss: 0.0084
# 第3代第10个染色体的适应度为0.857287
# 此染色体为： [1, 1, 123, 36, 0.2, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 18ms/step - loss: 0.0986 - val_loss: 0.0435
# Epoch 2/3
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0314 - val_loss: 0.0146
# Epoch 3/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0089 - val_loss: 0.0076
# 第3代第11个染色体的适应度为0.855263
# 此染色体为： [1, 1, 106, 125, 0.4, 3]
# Epoch 1/2
# 85/85 [==============================] - 3s 15ms/step - loss: 0.1754 - val_loss: 0.0874
# Epoch 2/2
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0663 - val_loss: 0.0343
# 第3代第12个染色体的适应度为0.835020
# 此染色体为： [1, 2, 54, 123, 126, 0.4, 2]
# Epoch 1/3
# 85/85 [==============================] - 3s 19ms/step - loss: 0.0936 - val_loss: 0.0548
# Epoch 2/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0442 - val_loss: 0.0275
# Epoch 3/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0206 - val_loss: 0.0139- ETA: 0s - l
# 第3代第13个染色体的适应度为0.849190
# 此染色体为： [1, 1, 90, 102, 0.5, 3]
# 85/85 [==============================] - 5s 36ms/step - loss: 0.0871 - val_loss: 0.0474
# 第3代第14个染色体的适应度为0.802632
# 此染色体为： [2, 1, 123, 79, 109, 0.4, 1]
# Epoch 1/3
# 85/85 [==============================] - 3s 20ms/step - loss: 0.0695 - val_loss: 0.0361
# Epoch 2/3
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0268 - val_loss: 0.0177
# Epoch 3/3
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0101 - val_loss: 0.0080
# 第3代第15个染色体的适应度为0.855263
# 此染色体为： [1, 1, 123, 55, 0.3, 3]
# Epoch 1/2
# 85/85 [==============================] - 2s 14ms/step - loss: 0.0894 - val_loss: 0.0660
# Epoch 2/2
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0472 - val_loss: 0.0359
# 第3代第16个染色体的适应度为0.844130
# 此染色体为： [1, 2, 42, 50, 50, 0.3, 2]
# Epoch 1/3
# 85/85 [==============================] - 3s 18ms/step - loss: 0.1852 - val_loss: 0.1113
# Epoch 2/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0921 - val_loss: 0.0576
# Epoch 3/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0450 - val_loss: 0.0300
# 第3代第17个染色体的适应度为0.854251
# 此染色体为： [1, 2, 90, 121, 74, 0.3, 3]
# Epoch 1/3
# 85/85 [==============================] - 2s 13ms/step - loss: 0.0721 - val_loss: 0.0423
# Epoch 2/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0347 - val_loss: 0.0238
# Epoch 3/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0186 - val_loss: 0.0147
# 第3代第18个染色体的适应度为0.821862
# 此染色体为： [1, 1, 54, 78, 0.4, 3]
# 85/85 [==============================] - 2s 15ms/step - loss: 0.1556 - val_loss: 0.0918
# 第3代第19个染色体的适应度为0.689271
# 此染色体为： [1, 2, 51, 113, 92, 0.3, 1]
# 85/85 [==============================] - 5s 27ms/step - loss: 0.1577 - val_loss: 0.0928
# 第3代第20个染色体的适应度为0.824899
# 此染色体为： [2, 2, 36, 77, 86, 84, 0, 1, 0.3, 1]
# 85/85 [==============================] - 5s 33ms/step - loss: 0.0635 - val_loss: 0.0365
# 第3代第21个染色体的适应度为0.777328
# 此染色体为： [2, 1, 89, 102, 51, 0.3, 1]
# Epoch 1/3
# 85/85 [==============================] - 5s 32ms/step - loss: 0.0646 - val_loss: 0.0392
# Epoch 2/3
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0246 - val_loss: 0.0199
# Epoch 3/3
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0091 - val_loss: 0.0222
# 第3代第22个染色体的适应度为0.851215
# 此染色体为： [2, 1, 111, 47, 124, 0.4, 3]
# 85/85 [==============================] - 5s 33ms/step - loss: 0.0879 - val_loss: 0.0497
# 第3代第23个染色体的适应度为0.836032
# 此染色体为： [2, 1, 74, 98, 101, 0.4, 1]
# 85/85 [==============================] - 2s 13ms/step - loss: 0.0616 - val_loss: 0.0368
# 第3代第24个染色体的适应度为0.825911
# 此染色体为： [1, 1, 47, 103, 0.2, 1]
# Epoch 1/2
# 85/85 [==============================] - 5s 33ms/step - loss: 0.1227 - val_loss: 0.0685
# Epoch 2/2
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0472 - val_loss: 0.0332
# 第3代第25个染色体的适应度为0.823887
# 此染色体为： [2, 2, 90, 101, 48, 127, 0, 2, 0.3, 1]
# 85/85 [==============================] - 5s 36ms/step - loss: 0.0886 - val_loss: 0.0418
# 第3代第26个染色体的适应度为0.815789
# 此染色体为： [2, 1, 109, 91, 120, 0.3, 1]
# Epoch 1/3
# 85/85 [==============================] - 3s 13ms/step - loss: 0.1398 - val_loss: 0.0937
# Epoch 2/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0792 - val_loss: 0.0606
# Epoch 3/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0475 - val_loss: 0.0440
# 第3代第27个染色体的适应度为0.754049
# 此染色体为： [1, 2, 43, 125, 47, 0.1, 3]
# Epoch 1/2
# 85/85 [==============================] - 3s 21ms/step - loss: 0.1008 - val_loss: 0.0497
# Epoch 2/2
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0365 - val_loss: 0.0182
# 第3代第28个染色体的适应度为0.823887
# 此染色体为： [1, 1, 124, 103, 0.4, 2]
# Epoch 1/3
# 85/85 [==============================] - 6s 39ms/step - loss: 0.0560 - val_loss: 0.0341
# Epoch 2/3
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0237 - val_loss: 0.0193
# Epoch 3/3
# 85/85 [==============================] - 2s 21ms/step - loss: 0.0097 - val_loss: 0.0122
# 第3代第29个染色体的适应度为0.852227
# 此染色体为： [2, 1, 103, 44, 91, 0.2, 3]
# Epoch 1/2
# 85/85 [==============================] - 2s 11ms/step - loss: 0.0485 - val_loss: 0.0315
# Epoch 2/2
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0265 - val_loss: 0.0236
# 第3代第30个染色体的适应度为0.750000
# 此染色体为： [1, 1, 33, 38, 0.5, 2]
# 85/85 [==============================] - 2s 14ms/step - loss: 0.0762 - val_loss: 0.0401
# 第3代第31个染色体的适应度为0.646761
# 此染色体为： [1, 1, 61, 126, 0.3, 1]
# Epoch 1/3
# 85/85 [==============================] - 3s 19ms/step - loss: 0.1480 - val_loss: 0.0807
# Epoch 2/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0627 - val_loss: 0.0340
# Epoch 3/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0240 - val_loss: 0.0164
# 第3代第32个染色体的适应度为0.842105
# 此染色体为： [1, 2, 101, 70, 98, 0.3, 3]
# Epoch 1/2
# 85/85 [==============================] - 5s 33ms/step - loss: 0.1384 - val_loss: 0.0778
# Epoch 2/2
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0568 - val_loss: 0.0364
# 第3代第33个染色体的适应度为0.846154
# 此染色体为： [2, 2, 116, 69, 79, 83, 0, 2, 0.2, 2]
# 85/85 [==============================] - 5s 31ms/step - loss: 0.0562 - val_loss: 0.0426
# 第3代第34个染色体的适应度为0.763158
# 此染色体为： [2, 1, 113, 68, 45, 0.5, 1]
# 85/85 [==============================] - 5s 29ms/step - loss: 0.0631 - val_loss: 0.0390
# 第3代第35个染色体的适应度为0.850202
# 此染色体为： [2, 1, 84, 62, 68, 0.2, 1]
# 85/85 [==============================] - 6s 38ms/step - loss: 0.1253 - val_loss: 0.0679
# 第3代第36个染色体的适应度为0.852227
# 此染色体为： [2, 2, 122, 85, 62, 82, 0, 1, 0.4, 1]
# 85/85 [==============================] - 3s 17ms/step - loss: 0.1788 - val_loss: 0.0959
# 第3代第37个染色体的适应度为0.811741
# 此染色体为： [1, 2, 79, 110, 106, 0.3, 1]
# Epoch 1/2
# 85/85 [==============================] - 5s 35ms/step - loss: 0.0755 - val_loss: 0.0427
# Epoch 2/2
# 85/85 [==============================] - 2s 27ms/step - loss: 0.0290 - val_loss: 0.0196
# 第3代第38个染色体的适应度为0.846154
# 此染色体为： [2, 1, 93, 110, 65, 0.2, 2]
# Epoch 1/3
# 85/85 [==============================] - 5s 31ms/step - loss: 0.0964 - val_loss: 0.0482
# Epoch 2/3
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0335 - val_loss: 0.0200
# Epoch 3/3
# 85/85 [==============================] - 2s 22ms/step - loss: 0.0109 - val_loss: 0.0167
# 第3代第39个染色体的适应度为0.847166
# 此染色体为： [2, 1, 56, 94, 119, 0.1, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 17ms/step - loss: 0.1399 - val_loss: 0.0908
# Epoch 2/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0701 - val_loss: 0.0430
# Epoch 3/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0340 - val_loss: 0.0281
# 第3代第40个染色体的适应度为0.826923
# 此染色体为： [1, 2, 104, 76, 47, 0.4, 3]
# Epoch 1/2
# 85/85 [==============================] - 3s 19ms/step - loss: 0.0756 - val_loss: 0.0363
# Epoch 2/2
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0251 - val_loss: 0.0129
# 第3代第41个染色体的适应度为0.835020
# 此染色体为： [1, 1, 126, 71, 0.3, 2]
# 85/85 [==============================] - 3s 20ms/step - loss: 0.0895 - val_loss: 0.0555
# 第3代第42个染色体的适应度为0.782389
# 此染色体为： [1, 2, 113, 34, 56, 0.3, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 16ms/step - loss: 0.1378 - val_loss: 0.0755
# Epoch 2/2
# 85/85 [==============================] - 1s 12ms/step - loss: 0.0576 - val_loss: 0.0449
# 第3代第43个染色体的适应度为0.754049
# 此染色体为： [1, 2, 82, 109, 42, 0.5, 2]
# 85/85 [==============================] - 4s 26ms/step - loss: 0.0612 - val_loss: 0.0384
# 第3代第44个染色体的适应度为0.713563
# 此染色体为： [2, 1, 67, 55, 43, 0.4, 1]
# Epoch 1/2
# 85/85 [==============================] - 2s 14ms/step - loss: 0.1373 - val_loss: 0.0775
# Epoch 2/2
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0622 - val_loss: 0.0381
# 第3代第45个染色体的适应度为0.816802
# 此染色体为： [1, 2, 64, 86, 73, 0.4, 2]
# Epoch 1/3
# 85/85 [==============================] - 3s 20ms/step - loss: 0.0713 - val_loss: 0.0442
# Epoch 2/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0335 - val_loss: 0.0219
# Epoch 3/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0162 - val_loss: 0.0122
# 第3代第46个染色体的适应度为0.857287
# 此染色体为： [1, 1, 116, 51, 0.5, 3]
# Epoch 1/2
# 85/85 [==============================] - 3s 17ms/step - loss: 0.1398 - val_loss: 0.0818
# Epoch 2/2
# 85/85 [==============================] - 1s 12ms/step - loss: 0.0619 - val_loss: 0.0385
# 第3代第47个染色体的适应度为0.808704
# 此染色体为： [1, 2, 101, 61, 100, 0.4, 2]
# 85/85 [==============================] - 3s 17ms/step - loss: 0.1316 - val_loss: 0.0792
# 第3代第48个染色体的适应度为0.852227
# 此染色体为： [1, 2, 101, 56, 82, 0.2, 1]
# Epoch 1/2
# 85/85 [==============================] - 5s 35ms/step - loss: 0.1927 - val_loss: 0.0896
# Epoch 2/2
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0632 - val_loss: 0.0341
# 第3代第49个染色体的适应度为0.835020
# 此染色体为： [2, 2, 77, 115, 116, 99, 0, 2, 0.3, 2]
# 85/85 [==============================] - 3s 15ms/step - loss: 0.1124 - val_loss: 0.0691
# 第3代第50个染色体的适应度为0.718623
# 此染色体为： [1, 2, 72, 66, 36, 0.5, 1]
# Generation: 3 Most fitted DNA: [ 1.  2. 40. 77. 97.  0.  0.  0.] 适应度为： 0.8582995951417004
# Epoch 1/2
# 85/85 [==============================] - 5s 36ms/step - loss: 0.0635 - val_loss: 0.0424
# Epoch 2/2
# 85/85 [==============================] - 2s 26ms/step - loss: 0.0261 - val_loss: 0.0267
# 第4代第1个染色体的适应度为0.841093
# 此染色体为： [2, 1, 89, 112, 47, 0.3, 2]
# Epoch 1/3
# 85/85 [==============================] - 2s 12ms/step - loss: 0.0840 - val_loss: 0.0597
# Epoch 2/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0485 - val_loss: 0.0388
# Epoch 3/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0291 - val_loss: 0.0269
# 第4代第2个染色体的适应度为0.847166
# 此染色体为： [1, 2, 47, 34, 56, 0.1, 3]
# Epoch 1/2
# 85/85 [==============================] - 3s 19ms/step - loss: 0.0881 - val_loss: 0.0506
# Epoch 2/2
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0401 - val_loss: 0.0280
# 第4代第3个染色体的适应度为0.853239
# 此染色体为： [1, 1, 126, 71, 0.5, 2]
# Epoch 1/2
# 85/85 [==============================] - 3s 21ms/step - loss: 0.0707 - val_loss: 0.0420
# Epoch 2/2
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0300 - val_loss: 0.0219
# 第4代第4个染色体的适应度为0.847166
# 此染色体为： [1, 1, 123, 55, 0.5, 2]
# Epoch 1/2
# 85/85 [==============================] - 6s 37ms/step - loss: 0.1533 - val_loss: 0.0825
# Epoch 2/2
# 85/85 [==============================] - 2s 28ms/step - loss: 0.0599 - val_loss: 0.0378
# 第4代第5个染色体的适应度为0.828947
# 此染色体为： [2, 2, 116, 113, 79, 83, 0, 2, 0.5, 2]
# Epoch 1/2
# 85/85 [==============================] - 3s 18ms/step - loss: 0.1729 - val_loss: 0.1007
# Epoch 2/2
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0804 - val_loss: 0.0452
# 第4代第6个染色体的适应度为0.847166
# 此染色体为： [1, 2, 93, 121, 65, 0.4, 2]
# Epoch 1/2
# 85/85 [==============================] - 5s 33ms/step - loss: 0.1491 - val_loss: 0.0874
# Epoch 2/2
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0645 - val_loss: 0.0484
# 第4代第7个染色体的适应度为0.811741
# 此染色体为： [2, 2, 126, 69, 80, 83, 0, 2, 0.2, 3]
# Epoch 1/3
# 85/85 [==============================] - 2s 13ms/step - loss: 0.1356 - val_loss: 0.0892
# Epoch 2/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0697 - val_loss: 0.0462
# Epoch 3/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0356 - val_loss: 0.0288
# 第4代第8个染色体的适应度为0.806680
# 此染色体为： [1, 2, 51, 113, 50, 0.2, 3]
# Epoch 1/3
# 85/85 [==============================] - 2s 11ms/step - loss: 0.0834 - val_loss: 0.0611
# Epoch 2/3
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0458 - val_loss: 0.0370
# Epoch 3/3
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0239 - val_loss: 0.0258
# 第4代第9个染色体的适应度为0.828947
# 此染色体为： [1, 2, 33, 50, 50, 0.1, 3]
# 85/85 [==============================] - 3s 22ms/step - loss: 0.2176 - val_loss: 0.1001
# 第4代第10个染色体的适应度为0.828947
# 此染色体为： [1, 2, 127, 123, 126, 0.3, 1]
# Epoch 1/2
# 85/85 [==============================] - 5s 34ms/step - loss: 0.0830 - val_loss: 0.0465
# Epoch 2/2
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0320 - val_loss: 0.0244
# 第4代第11个染色体的适应度为0.816802
# 此染色体为： [2, 1, 123, 76, 109, 0.3, 2]
# Epoch 1/3
# 85/85 [==============================] - 2s 12ms/step - loss: 0.0802 - val_loss: 0.0587
# Epoch 2/3
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0483 - val_loss: 0.0386
# Epoch 3/3
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0299 - val_loss: 0.0273
# 第4代第12个染色体的适应度为0.852227
# 此染色体为： [1, 2, 42, 34, 42, 0.1, 3]
# Epoch 1/3
# 85/85 [==============================] - 2s 14ms/step - loss: 0.1498 - val_loss: 0.0785
# Epoch 2/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0592 - val_loss: 0.0333
# Epoch 3/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0211 - val_loss: 0.0346
# 第4代第13个染色体的适应度为0.838057
# 此染色体为： [1, 2, 51, 113, 92, 0.1, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 16ms/step - loss: 0.1600 - val_loss: 0.0978
# Epoch 2/3
# 85/85 [==============================] - 1s 12ms/step - loss: 0.0792 - val_loss: 0.0495
# Epoch 3/3
# 85/85 [==============================] - 1s 12ms/step - loss: 0.0390 - val_loss: 0.0258
# 第4代第14个染色体的适应度为0.838057
# 此染色体为： [1, 2, 77, 125, 47, 0.5, 3]
# Epoch 1/3
# 85/85 [==============================] - 2s 11ms/step - loss: 0.0477 - val_loss: 0.0334
# Epoch 2/3
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0227 - val_loss: 0.0190
# Epoch 3/3
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# 第4代第15个染色体的适应度为0.832996
# 此染色体为： [1, 1, 38, 72, 0.1, 3]
# Epoch 1/3
# 85/85 [==============================] - 2s 11ms/step - loss: 0.1118 - val_loss: 0.0669
# Epoch 2/3
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0525 - val_loss: 0.0327
# Epoch 3/3
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0234 - val_loss: 0.0243
# 第4代第16个染色体的适应度为0.778340
# 此染色体为： [1, 2, 33, 61, 98, 0.1, 3]
# Epoch 1/2
# 85/85 [==============================] - 5s 31ms/step - loss: 0.1735 - val_loss: 0.0924
# Epoch 2/2
# 85/85 [==============================] - 2s 24ms/step - loss: 0.0678 - val_loss: 0.0411
# 第4代第17个染色体的适应度为0.841093
# 此染色体为： [2, 2, 96, 87, 110, 91, 0, 2, 0.5, 2]
# Epoch 1/2
# 85/85 [==============================] - 5s 32ms/step - loss: 0.1028 - val_loss: 0.0533
# Epoch 2/2
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0383 - val_loss: 0.0219
# 第4代第18个染色体的适应度为0.829960
# 此染色体为： [2, 1, 62, 110, 109, 0.5, 2]
# 85/85 [==============================] - 5s 36ms/step - loss: 0.0859 - val_loss: 0.0438
# 第4代第19个染色体的适应度为0.784413
# 此染色体为： [2, 1, 102, 119, 84, 0.5, 1]
# 85/85 [==============================] - 2s 13ms/step - loss: 0.0575 - val_loss: 0.0382
# 第4代第20个染色体的适应度为0.728745
# 此染色体为： [1, 1, 53, 58, 0.3, 1]
# 85/85 [==============================] - 4s 25ms/step - loss: 0.0725 - val_loss: 0.0459
# 第4代第21个染色体的适应度为0.827935
# 此染色体为： [2, 1, 48, 54, 106, 0.5, 1]
# Epoch 1/2
# 85/85 [==============================] - 5s 35ms/step - loss: 0.0736 - val_loss: 0.0376
# Epoch 2/2
# 85/85 [==============================] - 2s 27ms/step - loss: 0.0260 - val_loss: 0.0208
# 第4代第22个染色体的适应度为0.801619
# 此染色体为： [2, 1, 99, 116, 62, 0.3, 2]
# 85/85 [==============================] - 3s 16ms/step - loss: 0.1115 - val_loss: 0.0714
# 第4代第23个染色体的适应度为0.851215
# 此染色体为： [1, 2, 78, 40, 95, 0.1, 1]
# 85/85 [==============================] - 3s 16ms/step - loss: 0.0967 - val_loss: 0.0513
# 第4代第24个染色体的适应度为0.794534
# 此染色体为： [1, 1, 97, 103, 0.5, 1]
# Epoch 1/3
# 85/85 [==============================] - 3s 16ms/step - loss: 0.0965 - val_loss: 0.0553
# Epoch 2/3
# 85/85 [==============================] - 1s 12ms/step - loss: 0.0441 - val_loss: 0.0286
# Epoch 3/3
# 85/85 [==============================] - 1s 12ms/step - loss: 0.0196 - val_loss: 0.0183
# 第4代第25个染色体的适应度为0.822874
# 此染色体为： [1, 2, 80, 35, 106, 0.5, 3]
# 85/85 [==============================] - 3s 20ms/step - loss: 0.1918 - val_loss: 0.0844
# 第4代第26个染色体的适应度为0.849190
# 此染色体为： [1, 2, 124, 107, 119, 0.2, 1]
# 85/85 [==============================] - 3s 17ms/step - loss: 0.0878 - val_loss: 0.0424
# 第4代第27个染色体的适应度为0.730769
# 此染色体为： [1, 1, 87, 109, 0.1, 1]
# 85/85 [==============================] - 4s 26ms/step - loss: 0.0865 - val_loss: 0.0563
# 第4代第28个染色体的适应度为0.851215
# 此染色体为： [2, 2, 112, 32, 43, 124, 0, 1, 0.1, 1]
# 85/85 [==============================] - 5s 35ms/step - loss: 0.0934 - val_loss: 0.0488
# 第4代第29个染色体的适应度为0.773279
# 此染色体为： [2, 1, 118, 94, 111, 0.4, 1]
# 85/85 [==============================] - 4s 25ms/step - loss: 0.1455 - val_loss: 0.0828
# 第4代第30个染色体的适应度为0.830972
# 此染色体为： [2, 2, 51, 47, 103, 98, 0, 1, 0.4, 3]
# 85/85 [==============================] - 4s 25ms/step - loss: 0.0587 - val_loss: 0.0421
# 第4代第31个染色体的适应度为0.839069
# 此染色体为： [2, 1, 47, 56, 71, 0.5, 1]
# Epoch 1/3
# 85/85 [==============================] - 2s 11ms/step - loss: 0.0905 - val_loss: 0.0676
# Epoch 2/3
# 85/85 [==============================] - 1s 6ms/step - loss: 0.0453 - val_loss: 0.0396
# Epoch 3/3
# 85/85 [==============================] - 1s 6ms/step - loss: 0.0229 - val_loss: 0.0241
# 第4代第32个染色体的适应度为0.838057
# 此染色体为： [1, 2, 32, 72, 37, 0.5, 3]
# 85/85 [==============================] - 2s 13ms/step - loss: 0.1677 - val_loss: 0.0987
# 第4代第33个染色体的适应度为0.800607
# 此染色体为： [1, 2, 39, 114, 111, 0.3, 1]
# 85/85 [==============================] - 5s 30ms/step - loss: 0.0932 - val_loss: 0.0538
# 第4代第34个染色体的适应度为0.831984
# 此染色体为： [2, 2, 78, 96, 43, 50, 0, 1, 0.2, 2]
# Epoch 1/3
# 85/85 [==============================] - 2s 12ms/step - loss: 0.1080 - val_loss: 0.0678
# Epoch 2/3
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0545 - val_loss: 0.0389
# Epoch 3/3
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0270 - val_loss: 0.0237
# 第4代第35个染色体的适应度为0.856275
# 此染色体为： [1, 2, 40, 54, 84, 0.4, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 19ms/step - loss: 0.0690 - val_loss: 0.0418
# Epoch 2/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0326 - val_loss: 0.0235
# Epoch 3/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0168 - val_loss: 0.0143
# 第4代第36个染色体的适应度为0.843117
# 此染色体为： [1, 1, 89, 52, 0.3, 3]
# 85/85 [==============================] - 2s 14ms/step - loss: 0.0830 - val_loss: 0.0489
# 第4代第37个染色体的适应度为0.727733
# 此染色体为： [1, 1, 63, 122, 0.1, 1]
# 85/85 [==============================] - 5s 31ms/step - loss: 0.0906 - val_loss: 0.0480
# 第4代第38个染色体的适应度为0.824899
# 此染色体为： [2, 1, 54, 126, 77, 0.3, 1]
# 85/85 [==============================] - 5s 27ms/step - loss: 0.0437 - val_loss: 0.0311
# 第4代第39个染色体的适应度为0.776316
# 此染色体为： [2, 1, 103, 45, 39, 0.2, 1]
# 85/85 [==============================] - 3s 17ms/step - loss: 0.1914 - val_loss: 0.1040
# 第4代第40个染色体的适应度为0.784413
# 此染色体为： [1, 2, 98, 116, 94, 0.5, 1]
# 85/85 [==============================] - 3s 18ms/step - loss: 0.0555 - val_loss: 0.0411
# 第4代第41个染色体的适应度为0.667004
# 此染色体为： [1, 1, 75, 40, 0.4, 1]
# Epoch 1/2
# 85/85 [==============================] - 4s 22ms/step - loss: 0.0509 - val_loss: 0.0380
# Epoch 2/2
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0262 - val_loss: 0.0303
# 第4代第42个染色体的适应度为0.773279
# 此染色体为： [2, 1, 43, 35, 43, 0.2, 2]
# Epoch 1/3
# ...
# 第32代第49个染色体的适应度为0.784631
# 此染色体为： [1, 2, 72, 112, 85, 0.3, 2]
# Epoch 1/3
# 85/85 [==============================] - 3s 18ms/step - loss: 0.1563 - val_loss: 0.0945
# Epoch 2/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0814 - val_loss: 0.0480
# Epoch 3/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0413 - val_loss: 0.0245
# 第32代第50个染色体的适应度为0.813953
# 此染色体为： [1, 2, 88, 95, 58, 0.1, 3]
# Generation: 32 Most fitted DNA: [1.00e+00 2.00e+00 1.19e+02 7.90e+01 4.20e+01 0.00e+00 1.00e-01 2.00e+00] 适应度为： 0.8179979777553084
# Epoch 1/2
# 85/85 [==============================] - 3s 17ms/step - loss: 0.0767 - val_loss: 0.0437
# Epoch 2/2
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0392 - val_loss: 0.0245
# 第33代第1个染色体的适应度为0.810920
# 此染色体为： [1, 1, 54, 93, 0.2, 2]
# Epoch 1/2
# 85/85 [==============================] - 3s 13ms/step - loss: 0.0578 - val_loss: 0.0336
# Epoch 2/2
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0295 - val_loss: 0.0178
# 第33代第2个染色体的适应度为0.814965
# 此染色体为： [1, 1, 38, 115, 0.1, 2]
# Epoch 1/3
# 85/85 [==============================] - 3s 21ms/step - loss: 0.1696 - val_loss: 0.1020
# Epoch 2/3
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0884 - val_loss: 0.0534
# Epoch 3/3
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0465 - val_loss: 0.0279
# 第33代第3个染色体的适应度为0.814965
# 此染色体为： [1, 2, 124, 76, 81, 0.2, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 16ms/step - loss: 0.0860 - val_loss: 0.0490
# Epoch 2/3
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0445 - val_loss: 0.0287
# Epoch 3/3
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0260 - val_loss: 0.0165
# 第33代第4个染色体的适应度为0.806876
# 此染色体为： [1, 1, 56, 115, 0.3, 3]
# Epoch 1/2
# 85/85 [==============================] - 3s 12ms/step - loss: 0.0572 - val_loss: 0.0280
# Epoch 2/2
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0295 - val_loss: 0.0216
# 第33代第5个染色体的适应度为0.817998
# 此染色体为： [1, 1, 33, 36, 0.4, 2]
# Epoch 1/2
# 85/85 [==============================] - 3s 16ms/step - loss: 0.0814 - val_loss: 0.0430
# Epoch 2/2
# 85/85 [==============================] - 1s 11ms/step - loss: 0.0375 - val_loss: 0.0216
# 第33代第6个染色体的适应度为0.767442
# 此染色体为： [1, 1, 72, 86, 0.2, 2]
# 85/85 [==============================] - 3s 18ms/step - loss: 0.0808 - val_loss: 0.0421
# 第33代第7个染色体的适应度为0.739130
# 此染色体为： [1, 1, 63, 125, 0.3, 1]
# Epoch 1/3
# 85/85 [==============================] - 3s 20ms/step - loss: 0.1806 - val_loss: 0.1032
# Epoch 2/3
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0873 - val_loss: 0.0482
# Epoch 3/3
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0410 - val_loss: 0.0229
# 第33代第8个染色体的适应度为0.812942
# 此染色体为： [1, 2, 112, 99, 81, 0.2, 3]
# 85/85 [==============================] - 3s 15ms/step - loss: 0.0541 - val_loss: 0.0301
# 第33代第9个染色体的适应度为0.719919
# 此染色体为： [1, 1, 49, 34, 0.1, 1]
# 85/85 [==============================] - 3s 16ms/step - loss: 0.1406 - val_loss: 0.0870
# 第33代第10个染色体的适应度为0.699697
# 此染色体为： [1, 2, 42, 83, 67, 0.3, 1]
# Epoch 1/3
# 85/85 [==============================] - 3s 14ms/step - loss: 0.1001 - val_loss: 0.0653
# Epoch 2/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0594 - val_loss: 0.0407
# Epoch 3/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0369 - val_loss: 0.0249
# 第33代第11个染色体的适应度为0.815976
# 此染色体为： [1, 2, 49, 39, 81, 0.2, 3]
# 85/85 [==============================] - 3s 16ms/step - loss: 0.0560 - val_loss: 0.0331
# 第33代第12个染色体的适应度为0.816987
# 此染色体为： [1, 1, 49, 60, 0.2, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 19ms/step - loss: 0.1872 - val_loss: 0.1140
# Epoch 2/2
# 85/85 [==============================] - 1s 14ms/step - loss: 0.1002 - val_loss: 0.0615
# 第33代第13个染色体的适应度为0.811931
# 此染色体为： [1, 2, 92, 109, 69, 0.4, 2]
# Epoch 1/2
# 85/85 [==============================] - 3s 14ms/step - loss: 0.1339 - val_loss: 0.0751
# Epoch 2/2
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0642 - val_loss: 0.0347
# 第33代第14个染色体的适应度为0.809909
# 此染色体为： [1, 2, 42, 83, 91, 0.4, 2]
# 85/85 [==============================] - 3s 23ms/step - loss: 0.1476 - val_loss: 0.0914
# 第33代第15个染色体的适应度为0.816987
# 此染色体为： [1, 2, 119, 79, 42, 0.4, 1]
# Epoch 1/3
# 85/85 [==============================] - 3s 13ms/step - loss: 0.0672 - val_loss: 0.0372
# Epoch 2/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0341 - val_loss: 0.0225
# Epoch 3/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0205 - val_loss: 0.0135
# 第33代第16个染色体的适应度为0.815976
# 此染色体为： [1, 1, 39, 86, 0.2, 3]
# 85/85 [==============================] - 3s 22ms/step - loss: 0.1678 - val_loss: 0.1008
# 第33代第17个染色体的适应度为0.799798
# 此染色体为： [1, 2, 95, 87, 70, 0.5, 1]
# 85/85 [==============================] - 5s 36ms/step - loss: 0.1453 - val_loss: 0.0740
# 第33代第18个染色体的适应度为0.747219
# 此染色体为： [2, 2, 64, 101, 84, 61, 0, 1, 0.5, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 19ms/step - loss: 0.1649 - val_loss: 0.0964
# Epoch 2/2
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0842 - val_loss: 0.0498
# 第33代第19个染色体的适应度为0.807887
# 此染色体为： [1, 2, 106, 85, 60, 0.4, 2]
# Epoch 1/2
# 85/85 [==============================] - 6s 38ms/step - loss: 0.1374 - val_loss: 0.0748
# Epoch 2/2
# 85/85 [==============================] - 2s 27ms/step - loss: 0.0623 - val_loss: 0.0329
# 第33代第20个染色体的适应度为0.802831
# 此染色体为： [2, 2, 98, 91, 91, 42, 0, 2, 0.1, 2]
# Epoch 1/2
# 85/85 [==============================] - 3s 13ms/step - loss: 0.1683 - val_loss: 0.0999
# Epoch 2/2
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0856 - val_loss: 0.0505
# 第33代第21个染色体的适应度为0.813953
# 此染色体为： [1, 2, 37, 123, 121, 0.1, 2]
# 85/85 [==============================] - 3s 17ms/step - loss: 0.0536 - val_loss: 0.0317
# 第33代第22个染色体的适应度为0.806876
# 此染色体为： [1, 1, 77, 39, 0.2, 1]
# Epoch 1/3
# 85/85 [==============================] - 2s 14ms/step - loss: 0.1245 - val_loss: 0.0711
# Epoch 2/3
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0615 - val_loss: 0.0350
# Epoch 3/3
# 85/85 [==============================] - 1s 7ms/step - loss: 0.0306 - val_loss: 0.0174
# 第33代第23个染色体的适应度为0.814965
# 此染色体为： [1, 2, 33, 67, 112, 0.4, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 15ms/step - loss: 0.1433 - val_loss: 0.0887
# Epoch 2/3
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0782 - val_loss: 0.0487
# Epoch 3/3
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0435 - val_loss: 0.0270
# 第33代第24个染色体的适应度为0.811931
# 此染色体为： [1, 2, 54, 120, 47, 0.3, 3]
# Epoch 1/2
# 85/85 [==============================] - 3s 19ms/step - loss: 0.1007 - val_loss: 0.0496
# Epoch 2/2
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0405 - val_loss: 0.0190
# 第33代第25个染色体的适应度为0.810920
# 此染色体为： [1, 1, 103, 121, 0.2, 2]
# Epoch 1/2
# 85/85 [==============================] - 3s 16ms/step - loss: 0.1470 - val_loss: 0.0864
# Epoch 2/2
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0787 - val_loss: 0.0518
# 第33代第26个染色体的适应度为0.801820
# 此染色体为： [1, 2, 38, 121, 51, 0.5, 2]
# 85/85 [==============================] - 3s 21ms/step - loss: 0.1801 - val_loss: 0.0927
# 第33代第27个染色体的适应度为0.728008
# 此染色体为： [1, 2, 119, 84, 123, 0.4, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 21ms/step - loss: 0.1691 - val_loss: 0.0945
# Epoch 2/2
# 85/85 [==============================] - 1s 16ms/step - loss: 0.0792 - val_loss: 0.0422
# 第33代第28个染色体的适应度为0.813953
# 此染色体为： [1, 2, 113, 72, 123, 0.2, 2]
# Epoch 1/2
# 85/85 [==============================] - 6s 38ms/step - loss: 0.1374 - val_loss: 0.0714
# Epoch 2/2
# 85/85 [==============================] - 2s 28ms/step - loss: 0.0585 - val_loss: 0.0288
# 第33代第29个染色体的适应度为0.809909
# 此染色体为： [2, 2, 124, 77, 92, 57, 0, 2, 0.2, 1]
# 85/85 [==============================] - 3s 21ms/step - loss: 0.1651 - val_loss: 0.0884
# 第33代第30个染色体的适应度为0.810920
# 此染色体为： [1, 2, 122, 73, 107, 0.1, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 14ms/step - loss: 0.1267 - val_loss: 0.0801
# Epoch 2/2
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0714 - val_loss: 0.0455
# 第33代第31个染色体的适应度为0.810920
# 此染色体为： [1, 2, 47, 99, 45, 0.3, 2]
# 85/85 [==============================] - 3s 21ms/step - loss: 0.1844 - val_loss: 0.0969
# 第33代第32个染色体的适应度为0.812942
# 此染色体为： [1, 2, 112, 87, 113, 0.1, 1]
# 85/85 [==============================] - 3s 14ms/step - loss: 0.1455 - val_loss: 0.0926
# 第33代第33个染色体的适应度为0.799798
# 此染色体为： [1, 2, 47, 66, 92, 0.5, 1]
# 85/85 [==============================] - 3s 21ms/step - loss: 0.1518 - val_loss: 0.0959
# 第33代第34个染色体的适应度为0.747219
# 此染色体为： [1, 2, 92, 61, 72, 0.5, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 18ms/step - loss: 0.0818 - val_loss: 0.0450
# Epoch 2/2
# 85/85 [==============================] - 1s 12ms/step - loss: 0.0393 - val_loss: 0.0227
# 第33代第35个染色体的适应度为0.814965
# 此染色体为： [1, 1, 77, 77, 0.2, 2]
# Epoch 1/2
# 85/85 [==============================] - 3s 17ms/step - loss: 0.1743 - val_loss: 0.0917
# Epoch 2/2
# 85/85 [==============================] - 1s 12ms/step - loss: 0.0763 - val_loss: 0.0384
# 第33代第36个染色体的适应度为0.814965
# 此染色体为： [1, 2, 67, 111, 105, 0.4, 2]
# Epoch 1/3
# 85/85 [==============================] - 3s 17ms/step - loss: 0.1759 - val_loss: 0.0977
# Epoch 2/3
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0818 - val_loss: 0.0436
# Epoch 3/3
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0364 - val_loss: 0.0194
# 第33代第37个染色体的适应度为0.815976
# 此染色体为： [1, 2, 58, 109, 118, 0.1, 3]
# Epoch 1/2
# 85/85 [==============================] - 3s 13ms/step - loss: 0.1331 - val_loss: 0.0851
# Epoch 2/2
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0798 - val_loss: 0.0598
# 第33代第38个染色体的适应度为0.760364
# 此染色体为： [1, 2, 38, 69, 54, 0.3, 2]
# 85/85 [==============================] - 3s 19ms/step - loss: 0.1217 - val_loss: 0.0769
# 第33代第39个染色体的适应度为0.796764
# 此染色体为： [1, 2, 87, 60, 32, 0.4, 1]
# Epoch 1/3
# 85/85 [==============================] - 3s 14ms/step - loss: 0.1733 - val_loss: 0.1091
# Epoch 2/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0967 - val_loss: 0.0640
# Epoch 3/3
# 85/85 [==============================] - 1s 9ms/step - loss: 0.0569 - val_loss: 0.0381
# 第33代第40个染色体的适应度为0.815976
# 此染色体为： [1, 2, 49, 113, 90, 0.1, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 19ms/step - loss: 0.0806 - val_loss: 0.0439
# Epoch 2/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0389 - val_loss: 0.0224
# Epoch 3/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0200 - val_loss: 0.0113
# 第33代第41个染色体的适应度为0.813953
# 此染色体为： [1, 1, 99, 68, 0.4, 3]
# 85/85 [==============================] - 6s 36ms/step - loss: 0.1963 - val_loss: 0.0815
# 第33代第42个染色体的适应度为0.785642
# 此染色体为： [2, 2, 72, 96, 120, 123, 0, 1, 0.3, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 20ms/step - loss: 0.0918 - val_loss: 0.0528
# Epoch 2/2
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0466 - val_loss: 0.0287
# 第33代第43个染色体的适应度为0.814965
# 此染色体为： [1, 1, 107, 73, 0.2, 2]
# 85/85 [==============================] - 3s 18ms/step - loss: 0.1770 - val_loss: 0.1019
# 第33代第44个染色体的适应度为0.807887
# 此染色体为： [1, 2, 75, 124, 73, 0.2, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 18ms/step - loss: 0.0696 - val_loss: 0.0418
# Epoch 2/2
# 85/85 [==============================] - 1s 12ms/step - loss: 0.0378 - val_loss: 0.0237
# 第33代第45个染色体的适应度为0.809909
# 此染色体为： [1, 1, 71, 58, 0.3, 2]
# 85/85 [==============================] - 3s 16ms/step - loss: 0.0803 - val_loss: 0.0449
# 第33代第46个染色体的适应度为0.812942
# 此染色体为： [1, 1, 61, 76, 0.2, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 20ms/step - loss: 0.1026 - val_loss: 0.0490
# Epoch 2/2
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0398 - val_loss: 0.0180
# 第33代第47个染色体的适应度为0.812942
# 此染色体为： [1, 1, 113, 115, 0.4, 2]
# Epoch 1/3
# 85/85 [==============================] - 3s 18ms/step - loss: 0.1247 - val_loss: 0.0754
# Epoch 2/3
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0669 - val_loss: 0.0413
# Epoch 3/3
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0371 - val_loss: 0.0224
# 第33代第48个染色体的适应度为0.811931
# 此染色体为： [1, 2, 55, 87, 40, 0.3, 3]
# 85/85 [==============================] - 6s 37ms/step - loss: 0.0889 - val_loss: 0.0515
# 第33代第49个染色体的适应度为0.777553
# 此染色体为： [2, 2, 76, 97, 33, 50, 0, 1, 0.1, 1]
# 85/85 [==============================] - 3s 21ms/step - loss: 0.0764 - val_loss: 0.0466
# 第33代第50个染色体的适应度为0.810920
# 此染色体为： [1, 1, 122, 47, 0.1, 1]
# Generation: 33 Most fitted DNA: [ 1.   1.  33.  36.   0.   0.   0.3  1. ] 适应度为： 0.8179979777553084
# Epoch 1/2
# 85/85 [==============================] - 3s 18ms/step - loss: 0.0595 - val_loss: 0.0335
# Epoch 2/2
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0312 - val_loss: 0.0195
# 第34代第1个染色体的适应度为0.801820
# 此染色体为： [1, 1, 77, 39, 0.3, 2]
# 85/85 [==============================] - 3s 15ms/step - loss: 0.1463 - val_loss: 0.0886
# 第34代第2个染色体的适应度为0.765420
# 此染色体为： [1, 2, 49, 86, 81, 0.4, 1]
# Epoch 1/2
# 85/85 [==============================] - 2s 15ms/step - loss: 0.0594 - val_loss: 0.0343
# Epoch 2/2
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0310 - val_loss: 0.0204
# 第34代第3个染色体的适应度为0.791709
# 此染色体为： [1, 1, 39, 86, 0.1, 2]
# Epoch 1/3
# 85/85 [==============================] - 3s 13ms/step - loss: 0.0697 - val_loss: 0.0321
# Epoch 2/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0332 - val_loss: 0.0246
# Epoch 3/3
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0254 - val_loss: 0.0186
# 第34代第4个染色体的适应度为0.814965
# 此染色体为： [1, 1, 39, 39, 0.5, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 20ms/step - loss: 0.0921 - val_loss: 0.0510
# Epoch 2/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0436 - val_loss: 0.0241
# Epoch 3/3
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0209 - val_loss: 0.0115
# 第34代第5个染色体的适应度为0.812942
# 此染色体为： [1, 1, 102, 86, 0.2, 3]
# Epoch 1/3
# 85/85 [==============================] - 3s 20ms/step - loss: 0.1922 - val_loss: 0.1111
# Epoch 2/3
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0959 - val_loss: 0.0566
# Epoch 3/3
# 85/85 [==============================] - 1s 12ms/step - loss: 0.0492 - val_loss: 0.0291
# 第34代第6个染色体的适应度为0.815976
# 此染色体为： [1, 2, 75, 96, 120, 0.3, 3]
# 85/85 [==============================] - 3s 13ms/step - loss: 0.0860 - val_loss: 0.0570
# 第34代第7个染色体的适应度为0.811931
# 此染色体为： [1, 2, 37, 60, 32, 0.1, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 15ms/step - loss: 0.1189 - val_loss: 0.0680
# Epoch 2/2
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0581 - val_loss: 0.0322
# 第34代第8个染色体的适应度为0.816987
# 此染色体为： [1, 2, 38, 121, 51, 0.2, 2]
# 85/85 [==============================] - 3s 20ms/step - loss: 0.1493 - val_loss: 0.0903
# 第34代第9个染色体的适应度为0.811931
# 此染色体为： [1, 2, 92, 69, 72, 0.1, 1]
# 85/85 [==============================] - 5s 33ms/step - loss: 0.2015 - val_loss: 0.1051
# 第34代第10个染色体的适应度为0.802831
# 此染色体为： [2, 2, 72, 87, 113, 123, 0, 1, 0.4, 2]
# Epoch 1/2
# 85/85 [==============================] - 3s 13ms/step - loss: 0.1218 - val_loss: 0.0722
# Epoch 2/2
# 85/85 [==============================] - 1s 8ms/step - loss: 0.0676 - val_loss: 0.0502
# 第34代第11个染色体的适应度为0.811931
# 此染色体为： [1, 2, 42, 39, 91, 0.3, 2]
# 85/85 [==============================] - 3s 13ms/step - loss: 0.0592 - val_loss: 0.0302
# 第34代第12个染色体的适应度为0.810920
# 此染色体为： [1, 1, 45, 89, 0.4, 1]
# Epoch 1/2
# 85/85 [==============================] - 3s 18ms/step - loss: 0.1174 - val_loss: 0.0647
# Epoch 2/2
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0545 - val_loss: 0.0284
# 第34代第13个染色体的适应度为0.811931
# 此染色体为： [1, 2, 57, 54, 99, 0.3, 2]
# Epoch 1/2
# 85/85 [==============================] - 3s 15ms/step - loss: 0.0750 - val_loss: 0.0444
# Epoch 2/2
# 85/85 [==============================] - 1s 10ms/step - loss: 0.0419 - val_loss: 0.0295
# 第34代第14个染色体的适应度为0.815976
# 此染色体为： [1, 1, 56, 71, 0.4, 2]
# Epoch 1/2
# 85/85 [==============================] - 3s 15ms/step - loss: 0.1899 - val_loss: 0.1170
# Epoch 2/2
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1050 - val_loss: 0.0705
# 第34代第15个染色体的适应度为0.810920
# 此染色体为： [1, 2, 51, 107, 108, 0.5, 2]
